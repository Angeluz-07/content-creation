# %%
from pathlib import Path
import sys
grandgrandparent = Path.cwd().parent.parent
sys.path.append(str(grandgrandparent))

# %%
import importlib
import discovery.context

# Force reload the package
importlib.reload(discovery.context)
from discovery.context import ingester
from pathlib import Path
import os

video_folder = r"C:\Users\rmena\Desktop\dev\content-creation\discovery\.data\gold_samples\202605"

result = ingester.generate_transcriptions(str(Path(video_folder)))

# %%
from pprint import pprint
print(len(result))
pprint(result)

# %%
ingester.save_transcriptions(result)
