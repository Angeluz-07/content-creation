# %%
from pathlib import Path
import sys
grandparent = Path.cwd().parent
sys.path.append(str(grandparent))

# %% [markdown]
# # v3

# %%
import importlib
import domain.services.video_builder_.v3

# Force reload the package
importlib.reload(domain.services.video_builder_.v3)
from domain.services.video_builder_.v3 import VideoBuilderV3
from pathlib import Path

output_path = r"C:\Users\rmena\Desktop\dev\content-creation\shorts_production\notebooks"
temp_path = r"C:\Users\rmena\Desktop\dev\content-creation\shorts_production\notebooks"
vb = VideoBuilderV3(output_path, temp_path)


input_filepath = r"C:\Users\rmena\Desktop\dev\content-creation\shorts_production\notebooks\test.mp4"
font_path = r"C:\Users\rmena\Desktop\dev\content-creation\shorts_production\.data\assets\GoogleSans-Medium.ttf"

params = {
    "input_filepath": input_filepath,
    "watermark_text": "myWatermark",
    "output_filename":"testout",
    "debug_video_frame": True,
    "font_path": font_path,
    "x_offset" : 0.7,
    "force_resize": True,
}
vb.build(params)
# Out:
# Resized file doesnt exists. Start resizing...
# Resizing video for mobile canvas...
# Resizing successful with file: C:\Users\rmena\Desktop\dev\content-creation\shorts_production\notebooks\test_resized.mp4
# DEBUG MODE: Generating one debug frame...
# 'C:\\Users\\rmena\\Desktop\\dev\\content-creation\\shorts_production\\notebooks\\debug_frame.png'

# %% [markdown]
# # V2

# %%
import importlib
import domain.services.video_builder_.v2

# Force reload the package
importlib.reload(domain.services.video_builder_.v2)
from domain.services.video_builder_.v2 import VideoBuilderV2
from pathlib import Path

output_path = r"C:\Users\rmena\Desktop\dev\content-creation\shorts_production\notebooks"
temp_path = r"C:\Users\rmena\Desktop\dev\content-creation\shorts_production\notebooks"
vb = VideoBuilderV2(output_path, temp_path)


input_filepath = r"C:\Users\rmena\Desktop\dev\content-creation\shorts_production\notebooks\test.mp4"
font_path = r"C:\Users\rmena\Desktop\dev\content-creation\shorts_production\.data\assets\GoogleSans-Medium.ttf"

params = {
    "input_filepath": input_filepath,
    "watermark_text": "myWatermark",
    "output_filename":"testout",
    "debug_video_frame": True,
    "hook_text": "El Macho\n\"aqui vamos de nuevo\"", 
    "frame_ts": "00:00:03",
    "font_path": font_path,
    "force_resize": True,
}
vb.build(params)
# Out:
# Resized file doesnt exists. Start resizing...
# Resizing video for mobile canvas...
# Resizing successful with file: C:\Users\rmena\Desktop\dev\content-creation\shorts_production\notebooks\test_resized.mp4
# Capturando frame en 00:00:03...
# Imagen guardada en: C:\Users\rmena\Desktop\dev\content-creation\shorts_production\notebooks\video_frame.png
# DEBUG MODE: Generating one debug frame...
# 'C:\\Users\\rmena\\Desktop\\dev\\content-creation\\shorts_production\\notebooks\\debug_frame.png'

# %% [markdown]
# # v1

# %%
import importlib
import domain.services.video_builder_.v1

# Force reload the package
importlib.reload(domain.services.video_builder_.v1)
from domain.services.video_builder_.v1 import VideoBuilderV1
from pathlib import Path

output_path = r"C:\Users\rmena\Desktop\dev\content-creation\shorts_production\notebooks"
temp_path = r"C:\Users\rmena\Desktop\dev\content-creation\shorts_production\notebooks"
vb = VideoBuilderV1(output_path, temp_path)


input_filepath = r"C:\Users\rmena\Desktop\dev\content-creation\shorts_production\notebooks\test.mp4"
font_path = r"C:\Users\rmena\Desktop\dev\content-creation\shorts_production\.data\assets\GoogleSans-Medium.ttf"
sticker_path = r"C:\Users\rmena\Desktop\dev\content-creation\shorts_production\.data\assets\emoji_comment.png"
params = {
    "input_filepath": input_filepath,
    "watermark_text": "myWatermark",
    "output_filename":"testout",
    "debug_video_frame": True,
    "hook_text": "El Macho\n\"aqui vamos de nuevo\"", 
    "font_path": font_path,
    "sticker_path": sticker_path,
    "force_resize": True,
}
vb.build(params)
# Out:
# Resized file doesnt exists. Start resizing...
# Resizing video for mobile canvas...
# Resizing successful with file: C:\Users\rmena\Desktop\dev\content-creation\shorts_production\notebooks\test_resized.mp4
# DEBUG MODE: Generating one debug frame...
# 'C:\\Users\\rmena\\Desktop\\dev\\content-creation\\shorts_production\\notebooks\\debug_frame.png'
