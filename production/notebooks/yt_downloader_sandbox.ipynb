# %%
from pathlib import Path
import sys
grandparent = Path.cwd().parent
sys.path.append(str(grandparent))

# %%
import importlib
import domain.services.yt_downloader 

# Force reload the package
importlib.reload(domain.services.yt_downloader)
from domain.services.yt_downloader import YTDownloader
from pathlib import Path

output_path = r"C:\Users\rmena\Desktop\dev\content-creation\shorts_production\notebooks"
ytd = YTDownloader(str(Path(output_path)))

url = "https://www.youtube.com/watch?v=c8lQiuWoItU&t=6224s"
start_ts = "00:00:10"
end_ts = "00:00:15"
force_download = True
output_filename = "testdownload"

ytd.get_vtt(url, force_download, output_filename)
# test it works
#ytd.get_video_segment(url, start_ts, end_ts, force_download, output_filename)
# Out:
# File doesnt exist or force_download=True, downloading...
# Starting download vtt (via Subprocess): https://www.youtube.com/watch?v=c8lQiuWoItU&t=6224s
# Elapsed time: 106.5122 seconds
# Raw segment downloaded successfully via Subprocess
# 'C:\\Users\\rmena\\Desktop\\dev\\content-creation\\shorts_production\\notebooks\\testdownload.vtt'
